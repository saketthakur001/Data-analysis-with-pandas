# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('pokemon.csv')
df
# Out:
#                        abilities  against_bug  against_dark  against_dragon  \
# 0    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 1    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 2    ['Overgrow', 'Chlorophyll']         1.00           1.0             1.0
# 3       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# 4       ['Blaze', 'Solar Power']         0.50           1.0             1.0
# ..                           ...          ...           ...             ...
# 796              ['Beast Boost']         0.25           1.0             0.5
# 797              ['Beast Boost']         1.00           1.0             0.5
# 798              ['Beast Boost']         2.00           0.5             2.0
# 799              ['Prism Armor']         2.00           2.0             1.0
# 800               ['Soul-Heart']         0.25           0.5             0.0
#
#      against_electric  against_fairy  against_fight  against_fire  \
# 0                 0.5            0.5            0.5           2.0
# 1                 0.5            0.5            0.5           2.0
# 2                 0.5            0.5            0.5           2.0
# 3                 1.0            0.5            1.0           0.5
# 4                 1.0            0.5            1.0           0.5
# ..                ...            ...            ...           ...
# 796               2.0            0.5            1.0           2.0
# 797               0.5            0.5            2.0           4.0
# 798               0.5            4.0            2.0           0.5
# 799               1.0            1.0            0.5           1.0
# 800               1.0            0.5            1.0           2.0
#
#      against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# 0               2.0            1.0  ...             88.1               1
# 1               2.0            1.0  ...             88.1               2
# 2               2.0            1.0  ...             88.1               3
# 3               1.0            1.0  ...             88.1               4
# 4               1.0            1.0  ...             88.1               5
# ..              ...            ...  ...              ...             ...
# 796             0.5            1.0  ...              NaN             797
# 797             1.0            1.0  ...              NaN             798
# 798             1.0            0.5  ...              NaN             799
# 799             1.0            2.0  ...              NaN             800
# 800             0.5            1.0  ...              NaN             801
#
#      sp_attack  sp_defense  speed    type1   type2  weight_kg  generation  \
# 0           65          65     45    grass  poison        6.9           1
# 1           80          80     60    grass  poison       13.0           1
# 2          122         120     80    grass  poison      100.0           1
# 3           60          50     65     fire     NaN        8.5           1
# 4           80          65     80     fire     NaN       19.0           1
# ..         ...         ...    ...      ...     ...        ...         ...
# 796        107         101     61    steel  flying      999.9           7
# 797         59          31    109    grass   steel        0.1           7
# 798         97          53     43     dark  dragon      888.0           7
# 799        127          89     79  psychic     NaN      230.0           7
# 800        130         115     65    steel   fairy       80.5           7
#
#      is_legendary
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ..            ...
# 796             1
# 797             1
# 798             1
# 799             1
# 800             1
#
# [801 rows x 41 columns]

# %%
df.shape
# Out:
# (801, 41)

# %%
df.describe()
# Out:
#        against_bug  against_dark  against_dragon  against_electric  \
# count   801.000000    801.000000      801.000000        801.000000
# mean      0.996255      1.057116        0.968789          1.073970
# std       0.597248      0.438142        0.353058          0.654962
# min       0.250000      0.250000        0.000000          0.000000
# 25%       0.500000      1.000000        1.000000          0.500000
# 50%       1.000000      1.000000        1.000000          1.000000
# 75%       1.000000      1.000000        1.000000          1.000000
# max       4.000000      4.000000        2.000000          4.000000
#
#        against_fairy  against_fight  against_fire  against_flying  \
# count     801.000000     801.000000    801.000000      801.000000
# mean        1.068976       1.065543      1.135456        1.192884
# std         0.522167       0.717251      0.691853        0.604488
# min         0.250000       0.000000      0.250000        0.250000
# 25%         1.000000       0.500000      0.500000        1.000000
# 50%         1.000000       1.000000      1.000000        1.000000
# 75%         1.000000       1.000000      2.000000        1.000000
# max         4.000000       4.000000      4.000000        4.000000
#
#        against_ghost  against_grass  ...    height_m          hp  \
# count     801.000000     801.000000  ...  781.000000  801.000000
# mean        0.985019       1.034020  ...    1.163892   68.958801
# std         0.558256       0.788896  ...    1.080326   26.576015
# min         0.000000       0.250000  ...    0.100000    1.000000
# 25%         1.000000       0.500000  ...    0.600000   50.000000
# 50%         1.000000       1.000000  ...    1.000000   65.000000
# 75%         1.000000       1.000000  ...    1.500000   80.000000
# max         4.000000       4.000000  ...   14.500000  255.000000
#
#        percentage_male  pokedex_number   sp_attack  sp_defense       speed  \
# count       703.000000      801.000000  801.000000  801.000000  801.000000
# mean         55.155761      401.000000   71.305868   70.911361   66.334582
# std          20.261623      231.373075   32.353826   27.942501   28.907662
# min           0.000000        1.000000   10.000000   20.000000    5.000000
# 25%          50.000000      201.000000   45.000000   50.000000   45.000000
# 50%          50.000000      401.000000   65.000000   66.000000   65.000000
# 75%          50.000000      601.000000   91.000000   90.000000   85.000000
# max         100.000000      801.000000  194.000000  230.000000  180.000000
#
#         weight_kg  generation  is_legendary
# count  781.000000  801.000000    801.000000
# mean    61.378105    3.690387      0.087391
# std    109.354766    1.930420      0.282583
# min      0.100000    1.000000      0.000000
# 25%      9.000000    2.000000      0.000000
# 50%     27.300000    4.000000      0.000000
# 75%     64.800000    5.000000      0.000000
# max    999.900000    7.000000      1.000000
#
# [8 rows x 34 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 41 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   abilities          801 non-null    object
#  1   against_bug        801 non-null    float64
#  2   against_dark       801 non-null    float64
#  3   against_dragon     801 non-null    float64
#  4   against_electric   801 non-null    float64
#  5   against_fairy      801 non-null    float64
#  6   against_fight      801 non-null    float64
#  7   against_fire       801 non-null    float64
#  8   against_flying     801 non-null    float64
#  9   against_ghost      801 non-null    float64
#  10  against_grass      801 non-null    float64
#  11  against_ground     801 non-null    float64
#  12  against_ice        801 non-null    float64
#  13  against_normal     801 non-null    float64
#  14  against_poison     801 non-null    float64
#  15  against_psychic    801 non-null    float64
#  16  against_rock       801 non-null    float64
#  17  against_steel      801 non-null    float64
#  18  against_water      801 non-null    float64
#  19  attack             801 non-null    int64
#  20  base_egg_steps     801 non-null    int64
#  21  base_happiness     801 non-null    int64
#  22  base_total         801 non-null    int64
#  23  capture_rate       801 non-null    object
#  24  classfication      801 non-null    object
#  25  defense            801 non-null    int64
#  26  experience_growth  801 non-null    int64
#  27  height_m           781 non-null    float64
#  28  hp                 801 non-null    int64
#  29  japanese_name      801 non-null    object
#  30  name               801 non-null    object
#  31  percentage_male    703 non-null    float64
#  32  pokedex_number     801 non-null    int64
#  33  sp_attack          801 non-null    int64
#  34  sp_defense         801 non-null    int64
#  35  speed              801 non-null    int64
#  36  type1              801 non-null    object
#  37  type2              417 non-null    object
#  38  weight_kg          781 non-null    float64
#  39  generation         801 non-null    int64
#  40  is_legendary       801 non-null    int64
# dtypes: float64(21), int64(13), object(7)
# memory usage: 256.7+ KB

# %%
df = df[['name', 'type1', 'type2', 'hp', 'attack', 'defense', 'sp_attack', 'sp_defense', 'speed', 'generation', 'is_legendary']]

# %%
df.loc[:, 'total'] = df[['hp', 'attack', 'defense', 'sp_attack', 'sp_defense', 'speed']].sum(axis=1)

df.insert(3, 'total', df.pop('total'))
df
# Out:
# /tmp/ipykernel_354483/336204881.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, 'total'] = df[['hp', 'attack', 'defense', 'sp_attack', 'sp_defense', 'speed']].sum(axis=1)
#            name    type1   type2  total   hp  attack  defense  sp_attack  \
# 0     Bulbasaur    grass  poison    318   45      49       49         65
# 1       Ivysaur    grass  poison    405   60      62       63         80
# 2      Venusaur    grass  poison    625   80     100      123        122
# 3    Charmander     fire     NaN    309   39      52       43         60
# 4    Charmeleon     fire     NaN    405   58      64       58         80
# ..          ...      ...     ...    ...  ...     ...      ...        ...
# 796  Celesteela    steel  flying    570   97     101      103        107
# 797     Kartana    grass   steel    570   59     181      131         59
# 798    Guzzlord     dark  dragon    570  223     101       53         97
# 799    Necrozma  psychic     NaN    600   97     107      101        127
# 800    Magearna    steel   fairy    600   80      95      115        130
#
#      sp_defense  speed  generation  is_legendary
# 0            65     45           1             0
# 1            80     60           1             0
# 2           120     80           1             0
# 3            50     65           1             0
# 4            65     80           1             0
# ..          ...    ...         ...           ...
# 796         101     61           7             1
# 797          31    109           7             1
# 798          53     43           7             1
# 799          89     79           7             1
# 800         115     65           7             1
#
# [801 rows x 12 columns]

# %%
df['type1'].value_counts().plot(kind='pie', autopct='%1.1f%%', cmap='tab20c', figsize=(10, 8))
# Out:
# <Axes: ylabel='count'>

# %%
df['total'].plot(kind='hist', figsize=(10, 8))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['total'].plot(kind='box', vert=False, figsize=(10, 5))
# Out:
# <Axes: >

# %%
df['is_legendary'].value_counts().plot(kind='pie', autopct='%1.1f%%', cmap='Set3', figsize=(10, 8))
# Out:
# <Axes: ylabel='count'>

# %%
sns.boxplot(data=df, x='attack')
# Out:
# <Axes: xlabel='attack'>

# %%
df.head(1)
# Out:
#         name  type1   type2  total  hp  attack  defense  sp_attack  \
# 0  Bulbasaur  grass  poison    318  45      49       49         65
#
#    sp_defense  speed  generation  is_legendary
# 0          65     45           1             0

# %%
df.loc[df['attack'] > 150]
# Out:
#           name    type1     type2  total   hp  attack  defense  sp_attack  \
# 126     Pinsir      bug       NaN    600   65     155      120         65
# 129   Gyarados    water    flying    640   95     155      109         70
# 213  Heracross      bug  fighting    600   80     185      115         40
# 247  Tyranitar     rock      dark    700  100     164      150         95
# 256   Blaziken     fire  fighting    630   80     160       80        130
# 288    Slaking   normal       NaN    670  150     160      100         95
# 353    Banette    ghost       NaN    555   64     165       75         93
# 382    Groudon   ground       NaN    770  100     180      160        150
# 383   Rayquaza   dragon    flying    780  105     180      100        180
# 408  Rampardos     rock       NaN    495   97     165       60         65
# 444   Garchomp   dragon    ground    700  108     170      115        120
# 474    Gallade  psychic  fighting    618   68     165       95         65
# 485  Regigigas   normal       NaN    670  110     160      110         80
# 718    Diancie     rock     fairy    700   50     160      110        160
# 719      Hoopa  psychic     ghost    680   80     160       60        170
# 797    Kartana    grass     steel    570   59     181      131         59
#
#      sp_defense  speed  generation  is_legendary
# 126          90    105           1             0
# 129         130     81           1             0
# 213         105     75           2             0
# 247         120     71           2             0
# 256          80    100           3             0
# 288          65    100           3             0
# 353          83     75           3             0
# 382          90     90           3             1
# 383         100    115           3             1
# 408          50     58           4             0
# 444          95     92           4             0
# 474         115    110           4             0
# 485         110    100           4             1
# 718         110    110           6             1
# 719         130     80           6             1
# 797          31    109           7             1

# %%
df.loc[df['speed'] <= 10]
# Out:
#           name   type1  type2  total   hp  attack  defense  sp_attack  \
# 212    Shuckle     bug   rock    505   20      10      230         10
# 327   Trapinch  ground    NaN    290   45     100       45         45
# 437     Bonsly    rock    NaN    290   50      80       95         10
# 445   Munchlax  normal    NaN    390  135      85       40         40
# 596  Ferroseed   grass  steel    305   44      50       91         24
# 770  Pyukumuku   water    NaN    410   55      60      130         30
#
#      sp_defense  speed  generation  is_legendary
# 212         230      5           2             0
# 327          45     10           3             0
# 437          45     10           4             0
# 445          85      5           4             0
# 596          86     10           5             0
# 770         130      5           7             0

# %%
slow_pokemons_df = df.loc[df['speed'] <= 10]
slow_pokemons_df
# Out:
#           name   type1  type2  total   hp  attack  defense  sp_attack  \
# 212    Shuckle     bug   rock    505   20      10      230         10
# 327   Trapinch  ground    NaN    290   45     100       45         45
# 437     Bonsly    rock    NaN    290   50      80       95         10
# 445   Munchlax  normal    NaN    390  135      85       40         40
# 596  Ferroseed   grass  steel    305   44      50       91         24
# 770  Pyukumuku   water    NaN    410   55      60      130         30
#
#      sp_defense  speed  generation  is_legendary
# 212         230      5           2             0
# 327          45     10           3             0
# 437          45     10           4             0
# 445          85      5           4             0
# 596          86     10           5             0
# 770         130      5           7             0

# %%
df.loc[df['sp_defense'] <=25]
# Out:
#            name   type1   type2  total   hp  attack  defense  sp_attack  \
# 9      Caterpie     bug     NaN    195   45      30       35         20
# 10      Metapod     bug     NaN    205   50      20       55         25
# 12       Weedle     bug  poison    195   40      35       30         20
# 13       Kakuna     bug  poison    205   45      25       50         25
# 38   Jigglypuff  normal   fairy    270  115      45       20         45
# 89     Shellder   water     NaN    305   30      65      100         45
# 97       Krabby   water     NaN    325   30     105       90         25
# 115      Horsea   water     NaN    295   30      40       70         70
# 128    Magikarp   water     NaN    200   20      10       55         15
# 173   Igglybuff  normal   fairy    210   90      30       15         40
# 193      Wooper   water  ground    210   55      45       45         25
# 265     Silcoon     bug     NaN    205   50      35       55         25
# 267     Cascoon     bug     NaN    205   50      35       55         25
# 292     Whismur  normal     NaN    240   64      51       23         51
# 317    Carvanha   water    dark    305   45      90       20         65
# 523  Roggenrola    rock     NaN    280   55      75       85         25
# 663  Scatterbug     bug     NaN    200   38      35       40         27
#
#      sp_defense  speed  generation  is_legendary
# 9            20     45           1             0
# 10           25     30           1             0
# 12           20     50           1             0
# 13           25     35           1             0
# 38           25     20           1             0
# 89           25     40           1             0
# 97           25     50           1             0
# 115          25     60           1             0
# 128          20     80           1             0
# 173          20     15           2             0
# 193          25     15           2             0
# 265          25     15           3             0
# 267          25     15           3             0
# 292          23     28           3             0
# 317          20     65           3             0
# 523          25     15           5             0
# 663          25     35           6             0

# %%
(df['sp_defense']<=25).sum()
# Out:
# np.int64(17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 801 entries, 0 to 800
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          801 non-null    object
#  1   type1         801 non-null    object
#  2   type2         417 non-null    object
#  3   total         801 non-null    int64
#  4   hp            801 non-null    int64
#  5   attack        801 non-null    int64
#  6   defense       801 non-null    int64
#  7   sp_attack     801 non-null    int64
#  8   sp_defense    801 non-null    int64
#  9   speed         801 non-null    int64
#  10  generation    801 non-null    int64
#  11  is_legendary  801 non-null    int64
# dtypes: int64(9), object(3)
# memory usage: 75.2+ KB

# %%
df['is_legendary'].sum()
# Out:
# np.int64(70)

# %%
df_legendary = df.loc[df['is_legendary'] == True]
df_legendary
# Out:
#            name     type1   type2  total   hp  attack  defense  sp_attack  \
# 143    Articuno       ice  flying    580   90      85      100         95
# 144      Zapdos  electric  flying    580   90      90       85        125
# 145     Moltres      fire  flying    580   90     100       90        125
# 149      Mewtwo   psychic     NaN    780  106     150       70        194
# 150         Mew   psychic     NaN    600  100     100      100        100
# ..          ...       ...     ...    ...  ...     ...      ...        ...
# 796  Celesteela     steel  flying    570   97     101      103        107
# 797     Kartana     grass   steel    570   59     181      131         59
# 798    Guzzlord      dark  dragon    570  223     101       53         97
# 799    Necrozma   psychic     NaN    600   97     107      101        127
# 800    Magearna     steel   fairy    600   80      95      115        130
#
#      sp_defense  speed  generation  is_legendary
# 143         125     85           1             1
# 144          90    100           1             1
# 145          85     90           1             1
# 149         120    140           1             1
# 150         100    100           1             1
# ..          ...    ...         ...           ...
# 796         101     61           7             1
# 797          31    109           7             1
# 798          53     43           7             1
# 799          89     79           7             1
# 800         115     65           7             1
#
# [70 rows x 12 columns]

# %%
egdf = pd.DataFrame([True, False, True, True])
~egdf
# Out:
#        0
# 0  False
# 1   True
# 2  False
# 3  False

# %%
ax = sns.scatterplot(data=df, x='defense', y='attack')
ax
# Out:
# <Axes: xlabel='defense', ylabel='attack'>

# %%
df.head()
# Out:
#          name  type1   type2  total  hp  attack  defense  sp_attack  \
# 0   Bulbasaur  grass  poison    318  45      49       49         65
# 1     Ivysaur  grass  poison    405  60      62       63         80
# 2    Venusaur  grass  poison    625  80     100      123        122
# 3  Charmander   fire     NaN    309  39      52       43         60
# 4  Charmeleon   fire     NaN    405  58      64       58         80
#
#    sp_defense  speed  generation  is_legendary
# 0          65     45           1             0
# 1          80     60           1             0
# 2         120     80           1             0
# 3          50     65           1             0
# 4          65     80           1             0

# %%
df.sort_values(by=['defense', 'attack'], ascending=[False, True])
# Out:
#          name     type1    type2  total   hp  attack  defense  sp_attack  \
# 212   Shuckle       bug     rock    505   20      10      230         10
# 207   Steelix     steel   ground    610   75     125      230         55
# 305    Aggron     steel     rock    630   70     140      230         60
# 376  Regirock      rock      NaN    580   80     100      200         50
# 712   Avalugg       ice      NaN    514   95     117      184         44
# ..        ...       ...      ...    ...  ...     ...      ...        ...
# 237  Smoochum       ice  psychic    305   45      30       15         85
# 171     Pichu  electric      NaN    205   20      40       15         35
# 241   Blissey    normal      NaN    540  255      10       10         75
# 112   Chansey    normal      NaN    450  250       5        5         35
# 439   Happiny    normal      NaN    220  100       5        5         15
#
#      sp_defense  speed  generation  is_legendary
# 212         230      5           2             0
# 207          95     30           2             0
# 305          80     50           3             0
# 376         100     50           3             1
# 712          46     28           6             0
# ..          ...    ...         ...           ...
# 237          65     65           2             0
# 171          35     60           2             0
# 241         135     55           2             0
# 112         105     50           1             0
# 439          65     30           4             0
#
# [801 rows x 12 columns]

# %%
df['type1'].unique()
# Out:
# array(['grass', 'fire', 'water', 'bug', 'normal', 'poison', 'electric',
#        'ground', 'fairy', 'fighting', 'psychic', 'rock', 'ghost', 'ice',
#        'dragon', 'dark', 'steel', 'flying'], dtype=object)

# %%
df[(df['type1'] == 'fire') & (df['type2']=='flying')]
# Out:
#             name type1   type2  total   hp  attack  defense  sp_attack  \
# 5      Charizard  fire  flying    634   78     104       78        159
# 145      Moltres  fire  flying    580   90     100       90        125
# 249        Ho-Oh  fire  flying    680  106     130       90        110
# 661  Fletchinder  fire  flying    382   62      73       55         56
# 662   Talonflame  fire  flying    499   78      81       71         74
# 740     Oricorio  fire  flying    476   75      70       70         98
#
#      sp_defense  speed  generation  is_legendary
# 5           115    100           1             0
# 145          85     90           1             1
# 249         154     90           2             1
# 661          52     84           6             0
# 662          69    126           6             0
# 740          70     93           7             0

# %%
df.query("`type1` == 'fire' and `type2` == 'flying'")
# Out:
#             name type1   type2  total   hp  attack  defense  sp_attack  \
# 5      Charizard  fire  flying    634   78     104       78        159
# 145      Moltres  fire  flying    580   90     100       90        125
# 249        Ho-Oh  fire  flying    680  106     130       90        110
# 661  Fletchinder  fire  flying    382   62      73       55         56
# 662   Talonflame  fire  flying    499   78      81       71         74
# 740     Oricorio  fire  flying    476   75      70       70         98
#
#      sp_defense  speed  generation  is_legendary
# 5           115    100           1             0
# 145          85     90           1             1
# 249         154     90           2             1
# 661          52     84           6             0
# 662          69    126           6             0
# 740          70     93           7             0

# %%
df.query("`type1` == 'fire' and not `type2` == 'flying'")
# Out:
#            name type1     type2  total   hp  attack  defense  sp_attack  \
# 3    Charmander  fire       NaN    309   39      52       43         60
# 4    Charmeleon  fire       NaN    405   58      64       58         80
# 36       Vulpix  fire       ice    299   38      41       40         50
# 37    Ninetales  fire       ice    505   73      67       75         81
# 57    Growlithe  fire       NaN    350   55      70       45         70
# 58     Arcanine  fire       NaN    555   90     110       80        100
# 76       Ponyta  fire       NaN    410   50      85       55         65
# 77     Rapidash  fire       NaN    500   65     100       70         80
# 125      Magmar  fire       NaN    495   65      95       57        100
# 135     Flareon  fire       NaN    525   65     130       60         95
# 154   Cyndaquil  fire       NaN    309   39      52       43         60
# 155     Quilava  fire       NaN    405   58      64       58         80
# 156  Typhlosion  fire       NaN    534   78      84       78        109
# 217      Slugma  fire       NaN    250   40      40       40         70
# 218    Magcargo  fire      rock    430   60      50      120         90
# 239       Magby  fire       NaN    365   45      75       37         70
# 243       Entei  fire       NaN    580  115     115       85         90
# 254     Torchic  fire       NaN    310   45      60       40         70
# 255   Combusken  fire  fighting    405   60      85       60         85
# 256    Blaziken  fire  fighting    630   80     160       80        130
# 321       Numel  fire    ground    305   60      60       40         65
# 322    Camerupt  fire    ground    560   70     120      100        145
# 323     Torkoal  fire       NaN    470   70      85      140         85
# 389    Chimchar  fire       NaN    309   44      58       44         58
# 390    Monferno  fire  fighting    405   64      78       52         78
# 391   Infernape  fire  fighting    534   76     104       71        104
# 466   Magmortar  fire       NaN    540   75      95       67        125
# 484     Heatran  fire     steel    600   91      90      106        130
# 497       Tepig  fire       NaN    308   65      63       45         45
# 498     Pignite  fire  fighting    418   90      93       55         70
# 499      Emboar  fire  fighting    528  110     123       65        100
# 512     Pansear  fire       NaN    316   50      53       48         53
# 513    Simisear  fire       NaN    498   75      98       63         98
# 553    Darumaka  fire       NaN    315   70      90       45         15
# 554  Darmanitan  fire      fire    540  105      30      105        140
# 630     Heatmor  fire       NaN    484   85      97       66        105
# 652    Fennekin  fire       NaN    307   40      45       40         62
# 653     Braixen  fire       NaN    409   59      59       58         90
# 654     Delphox  fire   psychic    534   75      69       72        114
# 666      Litleo  fire    normal    369   62      50       58         73
# 667      Pyroar  fire    normal    507   86      68       72        109
# 720   Volcanion  fire     water    600   80     110      120        130
# 724      Litten  fire       NaN    320   45      65       40         60
# 725    Torracat  fire       NaN    420   65      85       50         80
# 726  Incineroar  fire      dark    530   95     115       90         80
# 775  Turtonator  fire    dragon    485   60      78      135         91
#
#      sp_defense  speed  generation  is_legendary
# 3            50     65           1             0
# 4            65     80           1             0
# 36           65     65           1             0
# 37          100    109           1             0
# 57           50     60           1             0
# 58           80     95           1             0
# 76           65     90           1             0
# 77           80    105           1             0
# 125          85     93           1             0
# 135         110     65           1             0
# 154          50     65           2             0
# 155          65     80           2             0
# 156          85    100           2             0
# 217          40     20           2             0
# 218          80     30           2             0
# 239          55     83           2             0
# 243          75    100           2             1
# 254          50     45           3             0
# 255          60     55           3             0
# 256          80    100           3             0
# 321          45     35           3             0
# 322         105     20           3             0
# 323          70     20           3             0
# 389          44     61           4             0
# 390          52     81           4             0
# 391          71    108           4             0
# 466          95     83           4             0
# 484         106     77           4             1
# 497          45     45           5             0
# 498          55     55           5             0
# 499          65     65           5             0
# 512          48     64           5             0
# 513          63    101           5             0
# 553          45     50           5             0
# 554         105     55           5             0
# 630          66     65           5             0
# 652          60     60           6             0
# 653          70     73           6             0
# 654         100    104           6             0
# 666          54     72           6             0
# 667          66    106           6             0
# 720          90     70           6             1
# 724          40     70           7             0
# 725          50     90           7             0
# 726          90     60           7             0
# 775          85     36           7             0

# %%
df['type1'].value_counts()
# Out:
# type1
# water       114
# normal      105
# grass        78
# bug          72
# psychic      53
# fire         52
# rock         45
# electric     39
# poison       32
# ground       32
# dark         29
# fighting     28
# dragon       27
# ghost        27
# steel        24
# ice          23
# fairy        18
# flying        3
# Name: count, dtype: int64

# %%
((df['type1'] == 'fire') & (df['type2'] == 'flying')).sum()
# Out:
# np.int64(6)

# %%
df.query("`type1`=='poison' or `type2`=='poison'")
# Out:
#           name   type1   type2  total   hp  attack  defense  sp_attack  \
# 0    Bulbasaur   grass  poison    318   45      49       49         65
# 1      Ivysaur   grass  poison    405   60      62       63         80
# 2     Venusaur   grass  poison    625   80     100      123        122
# 12      Weedle     bug  poison    195   40      35       30         20
# 13      Kakuna     bug  poison    205   45      25       50         25
# ..         ...     ...     ...    ...  ...     ...      ...        ...
# 746   Mareanie  poison   water    305   50      53       62         43
# 747    Toxapex  poison   water    495   50      63      152         53
# 756   Salandit  poison    fire    320   48      44       40         71
# 757   Salazzle  poison    fire    480   68      64       60        111
# 792   Nihilego    rock  poison    570  109      53       47        127
#
#      sp_defense  speed  generation  is_legendary
# 0            65     45           1             0
# 1            80     60           1             0
# 2           120     80           1             0
# 12           20     50           1             0
# 13           25     35           1             0
# ..          ...    ...         ...           ...
# 746          52     45           7             0
# 747         142     35           7             0
# 756          40     77           7             0
# 757          60    117           7             0
# 792         131    103           7             1
#
# [64 rows x 12 columns]

# %%
df[(df['type1']=='poison') | (df['type2']=='poison')]
# Out:
#           name   type1   type2  total   hp  attack  defense  sp_attack  \
# 0    Bulbasaur   grass  poison    318   45      49       49         65
# 1      Ivysaur   grass  poison    405   60      62       63         80
# 2     Venusaur   grass  poison    625   80     100      123        122
# 12      Weedle     bug  poison    195   40      35       30         20
# 13      Kakuna     bug  poison    205   45      25       50         25
# ..         ...     ...     ...    ...  ...     ...      ...        ...
# 746   Mareanie  poison   water    305   50      53       62         43
# 747    Toxapex  poison   water    495   50      63      152         53
# 756   Salandit  poison    fire    320   48      44       40         71
# 757   Salazzle  poison    fire    480   68      64       60        111
# 792   Nihilego    rock  poison    570  109      53       47        127
#
#      sp_defense  speed  generation  is_legendary
# 0            65     45           1         False
# 1            80     60           1         False
# 2           120     80           1         False
# 12           20     50           1         False
# 13           25     35           1         False
# ..          ...    ...         ...           ...
# 746          52     45           7         False
# 747         142     35           7         False
# 756          40     77           7         False
# 757          60    117           7         False
# 792         131    103           7          True
#
# [64 rows x 12 columns]

# %%
df.query("`type1`=='poison' or `type2`=='poison'").shape
# Out:
# (64, 12)

# %%
df[(df['type1']=='poison') | (df['type2']=='poison')].shape
# Out:
# (64, 12)

# %%
df.sort_values('defense', ascending=False)[:1]
# Out:
#         name  type1   type2  total  hp  attack  defense  sp_attack  \
# 207  Steelix  steel  ground    610  75     125      230         55
#
#      sp_defense  speed  generation  is_legendary
# 207          95     30           2             0

# %%
# conver the 1 and 0 to True and False
df['is_legendary'] = df['is_legendary']==1

# the right way to do it is
df.iloc[:, 'is_legendary'] = df['is_legendary']==1

# %%
df.loc[df['is_legendary'], 'type1'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='type1'>

# %%
df.loc[(df['type1']=='water') & df['generation'].isin([1, 2, 3])].sort_values('total', ascending=False)
# Out:
#           name  type1    type2  total   hp  attack  defense  sp_attack  \
# 381     Kyogre  water      NaN    770  100     150       90        180
# 129   Gyarados  water   flying    640   95     155      109         70
# 259   Swampert  water   ground    635  100     150      110         95
# 8    Blastoise  water      NaN    630   79     103      120        135
# 79     Slowbro  water  psychic    590   95      75      180        130
# ..         ...    ...      ...    ...  ...     ...      ...        ...
# 182     Marill  water    fairy    250   70      20       50         20
# 269      Lotad  water    grass    220   40      30       30         40
# 193     Wooper  water   ground    210   55      45       45         25
# 128   Magikarp  water      NaN    200   20      10       55         15
# 348     Feebas  water      NaN    200   20      15       20         10
#
#      sp_defense  speed  generation  is_legendary
# 381         160     90           3          True
# 129         130     81           1         False
# 259         110     70           3         False
# 8           115     78           1         False
# 79           80     30           1         False
# ..          ...    ...         ...           ...
# 182          50     40           2         False
# 269          50     30           3         False
# 193          25     15           2         False
# 128          20     80           1         False
# 348          55     80           3         False
#
# [70 rows x 12 columns]

# %% [markdown]
# Most powerful dragon in last 2 generation

# %%
df[((df['type1']=='dragon') | (df['type2']=='drason')) & df['generation'].isin([6, 7])].sort_values('total', ascending=False)
# Out:
#          name   type1     type2  total   hp  attack  defense  sp_attack  \
# 717   Zygarde  dragon    ground    708  216     100      121         91
# 783   Kommo-o  dragon  fighting    600   75     110      125        100
# 705    Goodra  dragon       NaN    600   90     100       70        110
# 704   Sliggoo  dragon       NaN    452   68      75       53         83
# 782  Hakamo-o  dragon  fighting    420   55      75       90         65
# 703     Goomy  dragon       NaN    300   45      50       35         55
# 781  Jangmo-o  dragon       NaN    300   45      55       65         45
#
#      sp_defense  speed  generation  is_legendary
# 717          95     85           6          True
# 783         105     85           7         False
# 705         150     80           6         False
# 704         113     60           6         False
# 782          70     65           7         False
# 703          75     40           6         False
# 781          45     45           7         False

# %%
df.query("(`type1`=='dragon' or `type2`=='dragon') and `generation` in [6, 7]")
# Out:
#            name   type1     type2  total   hp  attack  defense  sp_attack  \
# 690    Dragalge  poison    dragon    494   65      75       90         97
# 695      Tyrunt    rock    dragon    362   58      89       77         45
# 696   Tyrantrum    rock    dragon    521   82     121      119         69
# 703       Goomy  dragon       NaN    300   45      50       35         55
# 704     Sliggoo  dragon       NaN    452   68      75       53         83
# 705      Goodra  dragon       NaN    600   90     100       70        110
# 713      Noibat  flying    dragon    245   40      30       35         45
# 714     Noivern  flying    dragon    535   85      70       80         97
# 717     Zygarde  dragon    ground    708  216     100      121         91
# 775  Turtonator    fire    dragon    485   60      78      135         91
# 779      Drampa  normal    dragon    485   78      60       85        135
# 781    Jangmo-o  dragon       NaN    300   45      55       65         45
# 782    Hakamo-o  dragon  fighting    420   55      75       90         65
# 783     Kommo-o  dragon  fighting    600   75     110      125        100
# 798    Guzzlord    dark    dragon    570  223     101       53         97
#
#      sp_defense  speed  generation  is_legendary
# 690         123     44           6         False
# 695          45     48           6         False
# 696          59     71           6         False
# 703          75     40           6         False
# 704         113     60           6         False
# 705         150     80           6         False
# 713          40     55           6         False
# 714          80    123           6         False
# 717          95     85           6          True
# 775          85     36           7         False
# 779          91     36           7         False
# 781          45     45           7         False
# 782          70     65           7         False
# 783         105     85           7         False
# 798          53     43           7          True

# %%
df[(df['attack']>100) & (df['type1']=='fire')]
# Out:
#            name type1     type2  total   hp  attack  defense  sp_attack  \
# 5     Charizard  fire    flying    634   78     104       78        159
# 58     Arcanine  fire       NaN    555   90     110       80        100
# 135     Flareon  fire       NaN    525   65     130       60         95
# 243       Entei  fire       NaN    580  115     115       85         90
# 249       Ho-Oh  fire    flying    680  106     130       90        110
# 256    Blaziken  fire  fighting    630   80     160       80        130
# 322    Camerupt  fire    ground    560   70     120      100        145
# 391   Infernape  fire  fighting    534   76     104       71        104
# 499      Emboar  fire  fighting    528  110     123       65        100
# 720   Volcanion  fire     water    600   80     110      120        130
# 726  Incineroar  fire      dark    530   95     115       90         80
#
#      sp_defense  speed  generation  is_legendary
# 5           115    100           1         False
# 58           80     95           1         False
# 135         110     65           1         False
# 243          75    100           2          True
# 249         154     90           2          True
# 256          80    100           3         False
# 322         105     20           3         False
# 391          71    108           4         False
# 499          65     65           5         False
# 720          90     70           6          True
# 726          90     60           7         False

# %%
df.query("`type1`=='fire' and `attack`>100")
# Out:
#            name type1     type2  total   hp  attack  defense  sp_attack  \
# 5     Charizard  fire    flying    634   78     104       78        159
# 58     Arcanine  fire       NaN    555   90     110       80        100
# 135     Flareon  fire       NaN    525   65     130       60         95
# 243       Entei  fire       NaN    580  115     115       85         90
# 249       Ho-Oh  fire    flying    680  106     130       90        110
# 256    Blaziken  fire  fighting    630   80     160       80        130
# 322    Camerupt  fire    ground    560   70     120      100        145
# 391   Infernape  fire  fighting    534   76     104       71        104
# 499      Emboar  fire  fighting    528  110     123       65        100
# 720   Volcanion  fire     water    600   80     110      120        130
# 726  Incineroar  fire      dark    530   95     115       90         80
#
#      sp_defense  speed  generation  is_legendary
# 5           115    100           1         False
# 58           80     95           1         False
# 135         110     65           1         False
# 243          75    100           2          True
# 249         154     90           2          True
# 256          80    100           3         False
# 322         105     20           3         False
# 391          71    108           4         False
# 499          65     65           5         False
# 720          90     70           6          True
# 726          90     60           7         False

# %%
water_flying_df = df.query("`type1`=='water' and `type2`=='flying'")
water_flying_df
# Out:
#          name  type1   type2  total  hp  attack  defense  sp_attack  \
# 129  Gyarados  water  flying    640  95     155      109         70
# 225   Mantine  water  flying    485  85      40       70         80
# 277   Wingull  water  flying    270  40      30       30         55
# 278  Pelipper  water  flying    440  60      50      100         95
# 457   Mantyke  water  flying    345  45      20       50         60
# 579  Ducklett  water  flying    305  62      44       50         44
# 580    Swanna  water  flying    473  75      87       63         87
#
#      sp_defense  speed  generation  is_legendary
# 129         130     81           1         False
# 225         140     70           2         False
# 277          30     85           3         False
# 278          70     65           3         False
# 457         120     50           4         False
# 579          50     55           5         False
# 580          63     98           5         False

# %%
legendary_fire_df = df.loc[(df['type1']=='fire') & df['is_legendary'], ['name', 'attack', 'generation']]
legendary_fire_df
# Out:
#           name  attack  generation
# 145    Moltres     100           1
# 243      Entei     115           2
# 249      Ho-Oh     130           2
# 484    Heatran      90           4
# 720  Volcanion     110           6

# %%
bottom_5 = df['speed'].quantile(.05)
top_5 = df['speed'].quantile(.50)
bottom_5, top_5
# Out:
# (np.float64(25.0), np.float64(65.0))

# %%
df.loc[(df['speed']<bottom_5) | (df['speed']>top_5)]
# Out:
#            name     type1     type2  total   hp  attack  defense  sp_attack  \
# 2      Venusaur     grass    poison    625   80     100      123        122
# 4    Charmeleon      fire       NaN    405   58      64       58         80
# 5     Charizard      fire    flying    634   78     104       78        159
# 8     Blastoise     water       NaN    630   79     103      120        135
# 11   Butterfree       bug    flying    395   60      45       50         90
# ..          ...       ...       ...    ...  ...     ...      ...        ...
# 793    Buzzwole       bug  fighting    570  107     139      139         53
# 794   Pheromosa       bug  fighting    570   71     137       37        137
# 795   Xurkitree  electric       NaN    570   83      89       71        173
# 797     Kartana     grass     steel    570   59     181      131         59
# 799    Necrozma   psychic       NaN    600   97     107      101        127
#
#      sp_defense  speed  generation  is_legendary
# 2           120     80           1         False
# 4            65     80           1         False
# 5           115    100           1         False
# 8           115     78           1         False
# 11           80     70           1         False
# ..          ...    ...         ...           ...
# 793          53     79           7          True
# 794          37    151           7          True
# 795          71     83           7          True
# 797          31    109           7          True
# 799          89     79           7          True
#
# [403 rows x 12 columns]

# %%
df.query(
    "speed < @bottom_5 or speed > @top_5"
)
# Out:
#            name     type1     type2  total   hp  attack  defense  sp_attack  \
# 2      Venusaur     grass    poison    625   80     100      123        122
# 4    Charmeleon      fire       NaN    405   58      64       58         80
# 5     Charizard      fire    flying    634   78     104       78        159
# 8     Blastoise     water       NaN    630   79     103      120        135
# 11   Butterfree       bug    flying    395   60      45       50         90
# ..          ...       ...       ...    ...  ...     ...      ...        ...
# 793    Buzzwole       bug  fighting    570  107     139      139         53
# 794   Pheromosa       bug  fighting    570   71     137       37        137
# 795   Xurkitree  electric       NaN    570   83      89       71        173
# 797     Kartana     grass     steel    570   59     181      131         59
# 799    Necrozma   psychic       NaN    600   97     107      101        127
#
#      sp_defense  speed  generation  is_legendary
# 2           120     80           1         False
# 4            65     80           1         False
# 5           115    100           1         False
# 8           115     78           1         False
# 11           80     70           1         False
# ..          ...    ...         ...           ...
# 793          53     79           7          True
# 794          37    151           7          True
# 795          71     83           7          True
# 797          31    109           7          True
# 799          89     79           7          True
#
# [403 rows x 12 columns]

# %%
df.loc[df['is_legendary']].sort_values(['attack', 'defense'], ascending=False).head(20)
# Out:
#           name    type1     type2  total   hp  attack  defense  sp_attack  \
# 797    Kartana    grass     steel    570   59     181      131         59
# 382    Groudon   ground       NaN    770  100     180      160        150
# 383   Rayquaza   dragon    flying    780  105     180      100        180
# 485  Regigigas   normal       NaN    670  110     160      110         80
# 718    Diancie     rock     fairy    700   50     160      110        160
# 719      Hoopa  psychic     ghost    680   80     160       60        170
# 643     Zekrom   dragon  electric    680  100     150      120        120
# 381     Kyogre    water       NaN    770  100     150       90        180
# 149     Mewtwo  psychic       NaN    780  106     150       70        194
# 644   Landorus   ground    flying    600   89     145       90        105
# 793   Buzzwole      bug  fighting    570  107     139      139         53
# 790   Solgaleo  psychic     steel    680  137     137      107        113
# 794  Pheromosa      bug  fighting    570   71     137       37        137
# 715    Xerneas    fairy       NaN    680  126     131       95        131
# 716    Yveltal     dark    flying    680  126     131       95        131
# 786  Tapu Bulu    grass     fairy    570   70     130      115         85
# 380     Latios   dragon   psychic    700   80     130      100        160
# 249      Ho-Oh     fire    flying    680  106     130       90        110
# 638  Terrakion     rock  fighting    580   91     129       90         72
# 647   Meloetta   normal   psychic    600  100     128       90         77
#
#      sp_defense  speed  generation  is_legendary
# 797          31    109           7          True
# 382          90     90           3          True
# 383         100    115           3          True
# 485         110    100           4          True
# 718         110    110           6          True
# 719         130     80           6          True
# 643         100     90           5          True
# 381         160     90           3          True
# 149         120    140           1          True
# 644          80     91           5          True
# 793          53     79           7          True
# 790          89     97           7          True
# 794          37    151           7          True
# 715          98     99           6          True
# 716          98     99           6          True
# 786          95     75           7          True
# 380         120    110           3          True
# 249         154     90           2          True
# 638          90    108           5          True
# 647          77    128           5          True
